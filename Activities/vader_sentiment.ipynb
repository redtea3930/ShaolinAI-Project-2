# %% [markdown]
# # Instructor Do: Intro to VADER Sentiment

# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nlpza\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
data = pd.read_csv('../Resources/beauty_reviews.csv')
data
# Out:
#                                            reviewText  label
# 0   its up to you but as per the poppyaustin.com s...      0
# 1   I didn't have this item in my home for more th...      0
# 2   Description states there should be 144 tattoos...      0
# 3   Agreed, this hair is nothing like what you act...      0
# 4                          Not quite what I expected!      0
# 5                                              Damage      0
# 6                                            Not good      0
# 7                                             no good      0
# 8   These "small" hair clips are the exact same si...      0
# 9   I put the strips on and when I lifted the stri...      0
# 10                         The suction is not working      0
# 11  This was a waste of money for what is was supp...      0
# 12  Extremely unhappy .......huge  let down. ...it...      0
# 13              tangles and falls apart, poor quality      0
# 14  I read that sponges need to be changed once a ...      1
# 15  Love the Capri Blue candles, and now I can wea...      1
# 16                      Works great, speedy delivery.      1
# 17  bought this at Sam's club with a friend  that ...      1
# 18  Have used Dr's Remedy base, topcoat, and polis...      1
# 19  I was perfect, and it looked wonderful with my...      1
# 20  Great product, adjustable, good quality, deliv...      1
# 21  So happy I took the plunge and bought this tow...      1
# 22          Just the right thing at a very nice price      1
# 23            Just like the description! works great.      1
# 24          Beautiful hair tie, big enough to notice.      1
# 25  lip liners are absolutely beautiful\r\nI shoul...      1
# 26                       Great blades and great price      1
# 27                                 Fun and works well      1
# 28  Ok, ladies. I never write reviews but.....I am...      1
# 29  This is very good for eczema and even more eff...      1
# 30         Love the shimmer and a chap stick as well.      1
# 31                                          Thanks!!!      1
# 32   Love it, and have been wearing this for 30 years      1
# 33  These brushes were a birthday gift for my 14 y...      1

# %%
# Create the Facebook Libra sentiment scores DataFrame
sentiments = []

for review in data["reviewText"]:
    try:
        sentiment = analyzer.polarity_scores(review)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            "text": review,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
sent_df = pd.DataFrame(sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
sent_df = sent_df[cols]

sent_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  its up to you but as per the poppyaustin.com s...   -0.7794     0.034
# 1  I didn't have this item in my home for more th...    0.3612     0.070
# 2  Description states there should be 144 tattoos...   -0.8313     0.000
# 3  Agreed, this hair is nothing like what you act...    0.4556     0.296
# 4                         Not quite what I expected!    0.0000     0.000
#
#    negative  neutral
# 0     0.132    0.835
# 1     0.000    0.930
# 2     0.291    0.709
# 3     0.123    0.581
# 4     0.000    1.000

# %%
# Get descriptive stats from the DataFrame
libra_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  99.000000  99.000000  99.000000  99.000000
# mean    0.260642   0.067091   0.017646   0.915273
# std     0.352937   0.062159   0.034538   0.073980
# min    -0.735100   0.000000   0.000000   0.710000
# 25%     0.000000   0.000000   0.000000   0.871500
# 50%     0.226300   0.057000   0.000000   0.926000
# 75%     0.548500   0.113000   0.014500   1.000000
# max     0.897900   0.225000   0.153000   1.000000
