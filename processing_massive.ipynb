# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from pathlib import Path
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
import re
def process_text(text): 
    sw = set(stopwords.words('english')) 
    regex = re.compile("[^a-zA-Z ]") 
    re_clean = regex.sub('', text) 
    words = word_tokenize(re_clean) 
    lem = [lemmatizer.lemmatize(word) for word in words] 
    output = ' '.join([word.lower() for word in lem if word.lower() not in sw]) 
    return output

# %%
massive = pd.read_csv('massive.csv')

# %%
massive.head()
# Out:
#             id   title  audienceScore  tomatoMeter   reviewId creationDate  \
# 0  adrift_2018  Adrift           65.0         69.0  102694850   2022-05-29
# 1  adrift_2018  Adrift           65.0         69.0  102654799   2022-02-11
# 2  adrift_2018  Adrift           65.0         69.0    2816011   2021-08-21
# 3  adrift_2018  Adrift           65.0         69.0    2812722   2021-08-11
# 4  adrift_2018  Adrift           65.0         69.0    2772153   2021-02-28
#
#        criticName  isTopCritic reviewState        publicatioName  \
# 0     Josh Parham        False       fresh     Next Best Picture
# 1   Cory Woodroof        False       fresh              615 Film
# 2      Kip Mooney        False      rotten  College Movie Review
# 3  Robin Holabird        False       fresh        Robin Holabird
# 4  Richard Crouse        False      rotten        Richard Crouse
#
#                                           reviewText scoreSentiment  delta
# 0  This is nowhere near the level of other great ...       POSITIVE    4.0
# 1  Adrift somehow survives the late reveal, and t...       POSITIVE    4.0
# 2  For almost the entire runtime, the only people...       NEGATIVE    4.0
# 3  Shailene Woodley shows no fear diving on and o...       POSITIVE    4.0
# 4  What is meant to be a voyage of self-discovery...       NEGATIVE    4.0

# %%
massive['reviewText'] = massive['reviewText'].apply(lambda x: process_text(x))
