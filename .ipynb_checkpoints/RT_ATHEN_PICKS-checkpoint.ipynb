# %%
#import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# read in cleaned CSV
filepath = Path('../massive.csv')
massive = pd.read_csv(filepath)
massive = massive.sample(n=15000)

# %%
massive.head(1)

# %%
# Dropping columns including audienceScore because it could unfairly help the model predict the delta. Leaving tomatoMeter to give the model a base of where the delta could be.
massive = massive.drop(columns=['id', 'reviewId', 'creationDate', 'isTopCritic', 'reviewState', 'audienceScore'])

# %%
massive.isnull().sum()

# %%
# Dropping duplicates
massive = massive.drop_duplicates(subset='reviewText', keep='first')
# Checking for duplicates
dup_df = massive.apply(lambda x: x.duplicated()).sum()
dup_df

# %%
sns.set(rc = {'figure.figsize':(6,3)})
sns.histplot(data=massive, x='publicatioName')

# %%
sns.set(rc = {'figure.figsize':(6,3)})
sns.histplot(data=massive, x='criticName')

# %%
massive.hist(column='delta', bins=100)

# %%
# define a function to process text on the data
lemmatizer = WordNetLemmatizer()
import re
def process_text(text): 
    sw = set(stopwords.words('english')) 
    regex = re.compile("[^a-zA-Z ]") 
    re_clean = regex.sub('', text) 
    words = word_tokenize(re_clean) 
    lem = [lemmatizer.lemmatize(word) for word in words] 
    output = ' '.join([word.lower() for word in lem if word.lower() not in sw]) 
    return output

# %%
# use a lambda x function to apple process text on the whole column.
massive['reviewText'] = massive['reviewText'].apply(lambda x: process_text(x))

# %%
# tfidf vectorizer for sentiment model
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X = tfidf_vectorizer.fit_transform(massive['reviewText'])
y = massive['scoreSentiment']

# %%
# Split the data into training and testing sets for sentiment model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

from sklearn.ensemble import GradientBoostingClassifier
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1] 
for learning_rate in learning_rates: 
    GBmodel = GradientBoostingClassifier(n_estimators=100, 
                                      learning_rate=learning_rate,
                                      max_features=2,
                                      max_depth=3,
                                      random_state=0)
    GBmodel.fit(X_train, y_train.ravel())
    print("Learning rate: ", learning_rate)
    # Score the model
    print("Accuracy score (training): {0:.3f}".format(
        GBmodel.score(
            X_train,
            y_train.ravel())))
    print("Accuracy score (validation): {0:.3f}".format(
        GBmodel.score(
            X_test,
            y_test.ravel())))
    print()

# %%
model.score(X_train, y_train)

# %%
model.score(X_test, y_test)

# %%
# Creating a dataframe made of the vectorized review text for the linear model
massive_features = pd.DataFrame(X.toarray(), columns=tfidf_vectorizer.get_feature_names())

# %%
massive_features.head(2)

# %%
# Need to rename column because title is also a column in massive_features
massive = massive.rename(columns={'title': 'title_'})

# %%
# Vectorizing original df to dense array for linear model
tfidf_dense = tfidf_vectorizer.fit_transform(massive['reviewText']).todense()

# Naming columns for each vectorized word and combining with original massive dataframe
new_cols = tfidf_vectorizer.get_feature_names()
combined = massive.join(pd.DataFrame(tfidf_dense, columns=new_cols))

# %%
# Dropping review text now that vectorized words are all columns
combined = combined.drop(columns=['reviewText'])

# %%
# Fill the nulls in all of the word columns with 0
combined = combined.fillna(0)

# %%
combined.isnull().sum().head(9)

# %%
# Renaming the least-appearing critics as Other to be encoded as the same critic later
counts = combined.criticName.value_counts()
threshold = combined.criticName.isin(counts.index[counts<16])
combined.loc[threshold, 'criticName'] = 'Other'
combined['criticName'].value_counts()

# %%
# Repeat for publications
counts = combined.publicatioName.value_counts()
threshold = combined.publicatioName.isin(counts.index[counts<12])
combined.loc[threshold, 'publicatioName'] = 'Other'
combined['publicatioName'].value_counts()

# %%
combined.head(1)

# %%
# list of columns to dummy
categorical_cols = ['title_', 'criticName', 'publicatioName', 'scoreSentiment'] 
# get dummies on categorical columns
combined = pd.get_dummies(combined, columns = categorical_cols)

# %%
X = combined.drop(columns=['delta'])
y = combined['delta']

# %%
X.isnull().sum().sum()

# %%
y.isnull().sum()

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.isnull().sum().sum()

# %%
# Scaling X
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
pca = PCA(n_components=500)
X_train_p = pca.fit_transform(X_train_sc)
X_test_p = pca.transform(X_test_sc)

# %%
# Choose a machine learning model (e.g., Logistic Regression) and train it
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1] 
for learning_rate in learning_rates: 
    GBmodel = GradientBoostingClassifier(n_estimators=100, 
                                      learning_rate=learning_rate,
                                      max_features=2,
                                      max_depth=3,
                                      random_state=69)
    GBmodel.fit(X_train_p, y_train.ravel())
    print("Learning rate: ", learning_rate)
    # Score the model
    print("Accuracy score (training): {0:.3f}".format(
        GBmodel.score(
            X_train_p,
            y_train.ravel())))
    print("Accuracy score (validation): {0:.3f}".format(
        GBmodel.score(
            X_test_p,
            y_test.ravel())))
    print()

# %%
model.score(X_train_p, y_train)

# %%
model.score(X_test_p, y_test)

# %%
massive_full = pd.read_csv(filepath)

# %%
massive_full = massive_full.sort_values(by='delta')
massive_full_20 = massive_full.head(20)

# %%
massive_full_sort = massive_full.sort_values(by='delta')
massive_full_asc_20 = massive_full_sort.head(20)
massive_full_desc_20 = massive_full_sort.tail(20)
massive_outliers = pd.concat([massive_full_asc_20, massive_full_desc_20], ignore_index=True)

# %%
massive.head(1)
# Out:
#                     id      title  audienceScore  tomatoMeter  reviewId  \
# 362289  duplicity_2009  Duplicity           37.0         65.0   1803847
#
#        creationDate    criticName  isTopCritic reviewState  \
# 362289   2009-03-23  Peter Rainer         True      rotten
#
#                    publicatioName  \
# 362289  Christian Science Monitor
#
#                                                reviewText scoreSentiment  \
# 362289  For all the glam and swank, the film is essent...       NEGATIVE
#
#         delta
# 362289   28.0

# %%
# Create a list of titles from the massive DataFrame
existing_titles = massive['title'].tolist()

# Use the isin() function to check if titles in massive_outliers exist in massive
mask = massive_outliers['title'].isin(existing_titles)

# Filter massive_outliers to keep only rows that don't exist in massive
massive_outliers = massive_outliers[~mask]

# %%
massive_outliers
# Out:
#                                     id                          title  \
# 0                    against_the_night              Against the Night
# 1                      finding_fatimah                Finding Fatimah
# 2   bad_kids_of_crestview_academy_2017  Bad Kids of Crestview Academy
# 3                       the_tutor_2023                      The Tutor
# 4                       the_tutor_2023                      The Tutor
# 5                       the_tutor_2023                      The Tutor
# 6                       the_tutor_2023                      The Tutor
# 7                       the_tutor_2023                      The Tutor
# 8             mrs_chatterjee_vs_norway      Mrs. Chatterjee vs Norway
# 9                       redeeming_love                 Redeeming Love
# 10                      redeeming_love                 Redeeming Love
# 11                      american_siege                 American Siege
# 12                      redeeming_love                 Redeeming Love
# 13                    the_black_prince               The Black Prince
# 14                        laal_kaptaan                   Laal Kaptaan
# 15                         division_19                    Division 19
# 16                        stoker_hills                   Stoker Hills
# 17               this_is_north_preston          This Is North Preston
# 18              1168378-broken_bridges                 Broken Bridges
# 19                      sensation_2021                      Sensation
# 20                        radio_dreams                   Radio Dreams
# 21                          unpregnant                     Unpregnant
# 22                          unpregnant                     Unpregnant
# 23                          unpregnant                     Unpregnant
# 24                          unpregnant                     Unpregnant
# 25                    stars_and_strife               Stars and Strife
# 26                        lowlife_love      Lowlife Love (Gesu no ai)
# 27                            dementer                       Dementer
# 28                            dementer                       Dementer
# 29                            dementer                       Dementer
# 30                            dementer                       Dementer
# 31                               fauci                          Fauci
# 32                               fauci                          Fauci
# 33                               fauci                          Fauci
# 34                               fauci                          Fauci
# 35                               fauci                          Fauci
# 36                               fauci                          Fauci
# 37                        my_best_part                   My Best Part
# 38                        my_best_part                   My Best Part
# 39                knock_down_the_house           Knock Down the House
#
#     audienceScore  tomatoMeter   reviewId creationDate        criticName  \
# 0            96.0          9.0    2467190   2018-03-25        Rob Hunter
# 1            99.0         13.0    2389567   2017-04-19       Tim Coleman
# 2            96.0         10.0    2633279   2019-10-07        Joey Keogh
# 3            92.0          7.0  102791069   2023-03-22      Julian Roman
# 4            92.0          7.0  102792039   2023-03-26  Jackie K. Cooper
# 5            92.0          7.0  102792473   2023-03-28       Joe Lipsett
# 6            92.0          7.0  102793721   2023-03-31       Tony Medley
# 7            92.0          7.0  102792424   2023-03-28  Keith Garlington
# 8            93.0          9.0  102789131   2023-03-16  Renuka Vyavahare
# 9            95.0         11.0    2853307   2022-01-20       Randy Myers
# 10           95.0         11.0  102652058   2022-02-04  Jackie K. Cooper
# 11           92.0          8.0  102695069   2022-05-31           Alan Ng
# 12           95.0         11.0    2852911   2022-01-18       Tessa Smith
# 13           90.0          7.0    2405027   2017-07-14     Stephen Romei
# 14           94.0         11.0    2638156   2019-10-22     Devesh Sharma
# 15           91.0          9.0    2608281   2019-07-24        Oscar Goff
# 16           99.0         17.0  102673841   2022-03-29   Martin Unsworth
# 17           99.0         17.0    2570453   2019-03-25     Andrew Parker
# 18           87.0          5.0    1603153   2007-03-01      Frank Lovece
# 19           95.0         13.0    2791533   2021-05-19        Rob Rector
# 20           20.0         95.0    2394150   2017-05-17         Wendy Ide
# 21           15.0         92.0    2722964   2020-09-11           Ty Burr
# 22           15.0         92.0    2721903   2020-09-08      Mark Jenkins
# 23           15.0         92.0    2723586   2020-09-12    Todd Jorgenson
# 24           15.0         92.0    2723754   2020-09-12        Sean Burns
# 25           12.0         90.0    2715389   2020-08-21      Wendy Shreve
# 26            0.0         80.0    2684427   2020-04-19      Emilie Black
# 27            0.0         83.0    2775299   2021-03-10       Keri O'Shea
# 28            0.0         83.0    2774669   2021-03-07       Joel Fisher
# 29            0.0         83.0    2774399   2021-03-06        Rich Cross
# 30            0.0         83.0    2698590   2020-06-24       Ryan Larson
# 31            2.0         86.0    2823446   2021-09-15       Danny Leigh
# 32            2.0         86.0    2839681   2021-11-15     Pradeep Menon
# 33            2.0         86.0    2832680   2021-10-18      Dan Schindel
# 34            2.0         86.0    2822985   2021-09-14      Armond White
# 35            2.0         86.0    2834224   2021-10-23      Jordan Ruimy
# 36            2.0         86.0    2821148   2021-09-09       Tony Medley
# 37            0.0         88.0  102660564   2022-02-22         Josh Bell
# 38            0.0         88.0  102663818   2022-03-03    Alan Zilberman
# 39           11.0         99.0    2700290   2020-06-30           CJ Sheu
#
#     isTopCritic reviewState              publicatioName  \
# 0         False       fresh         Film School Rejects
# 1         False       fresh                  Total Film
# 2         False       fresh               Wicked Horror
# 3         False       fresh                    MovieWeb
# 4         False       fresh           jackiekcooper.com
# 5         False       fresh           Bloody Disgusting
# 6         False       fresh     The Larchmont Chronicle
# 7         False       fresh   Arkansas Democrat-Gazette
# 8         False       fresh          The Times of India
# 9          True       fresh       San Jose Mercury News
# 10        False       fresh           jackiekcooper.com
# 11        False       fresh                 Film Threat
# 12        False       fresh                Mama's Geeky
# 13         True       fresh              The Australian
# 14        False       fresh                    Filmfare
# 15        False       fresh               Boston Hassle
# 16        False       fresh                   Starburst
# 17        False       fresh                    The Gate
# 18        False       fresh  Film Journal International
# 19        False       fresh                 Film Threat
# 20         True      rotten        Screen International
# 21         True      rotten                Boston Globe
# 22         True      rotten              Slant Magazine
# 23        False      rotten                 Cinemalogue
# 24        False      rotten          North Shore Movies
# 25        False      rotten              Featuring Film
# 26        False      rotten               Cinema Crazed
# 27        False      rotten          Warped Perspective
# 28        False      rotten   Battle Royale With Cheese
# 29        False      rotten                   Starburst
# 30        False      rotten            Ghastly Grinning
# 31         True      rotten             Financial Times
# 32        False      rotten                   Firstpost
# 33        False      rotten               Hyperallergic
# 34        False      rotten             National Review
# 35        False      rotten               World of Reel
# 36        False      rotten     The Larchmont Chronicle
# 37        False      rotten             Crooked Marquee
# 38        False      rotten            Spectrum Culture
# 39        False      rotten            Critics at Large
#
#                                            reviewText scoreSentiment  delta
# 0   A fun little horror movie making due on a clea...       POSITIVE  -87.0
# 1   There's real chemistry between the leads, and ...       POSITIVE  -86.0
# 2   Bad Kids Of Crestview Academy is bright, obnox...       POSITIVE  -86.0
# 3   The Tutor suffers from major logic flaws&#46; ...       POSITIVE  -85.0
# 4   Twisty enough to keep you interested till the ...       POSITIVE  -85.0
# 5   It&#8217;s not the evocative queer suspense fi...       POSITIVE  -85.0
# 6   This is a terrific little thriller that is inv...       POSITIVE  -85.0
# 7   For those able to avoid the traps of over-crit...       POSITIVE  -85.0
# 8   Amit Trivedi’s music embodies the spirit of a ...       POSITIVE  -84.0
# 9   "Love" might be best embraced by the faithful,...       POSITIVE  -84.0
# 10  A faithful adaptation of Francine Rivers' high...       POSITIVE  -84.0
# 11  The action moves smoothly and quickly with goo...       POSITIVE  -84.0
# 12  Full of drama and romance -- and just a touch ...       POSITIVE  -84.0
# 13  If you don't know much about Singh (as I didn'...       POSITIVE  -83.0
# 14  Superb production values, a nice background sc...       POSITIVE  -83.0
# 15  But in spite of her scrappy means, Halewood sh...       POSITIVE  -82.0
# 16  The conclusion might be a tad obvious but it w...       POSITIVE  -82.0
# 17  Hayman paints a thorough and complex picture t...       POSITIVE  -82.0
# 18  An imperfect but emotionally true and often ma...       POSITIVE  -82.0
# 19  There's still much to admire with Sensation, d...       POSITIVE  -82.0
# 20  Radio Dreams' aimless pacing and the character...       NEGATIVE   75.0
# 21  Veronica and Bailey deserve better. So do Rich...       NEGATIVE   77.0
# 22  Its few nutty ideas demonstrate how little dis...       NEGATIVE   77.0
# 23  Some charming performances can't offset the ov...       NEGATIVE   77.0
# 24  It plays like a very special episode of 'Sam &...       NEGATIVE   77.0
# 25  A feel-good Michael Moore, [Director David] Sm...       NEGATIVE   78.0
# 26  A lot of it feels as though the filmmaker is t...       NEGATIVE   80.0
# 27  Dementer sets out everything it's going to do ...       NEGATIVE   83.0
# 28  There are some great visuals towards the end a...       NEGATIVE   83.0
# 29  Dementer comes up short in trying to merge the...       NEGATIVE   83.0
# 30  It dabbles in cults, satanism, and psychosis. ...       NEGATIVE   83.0
# 31  An admiring film that still ends up doing him ...       NEGATIVE   84.0
# 32  [This] documentary on Anthony Fauci is too one...       NEGATIVE   84.0
# 33       Not quite a hagiography, but it comes close.       NEGATIVE   84.0
# 34  As so many media outlets have done, NG dispens...       NEGATIVE   84.0
# 35  This was a rather standard doc, plainly told. ...       NEGATIVE   84.0
# 36  ...a fawning no-warts paean to Fauci in which ...       NEGATIVE   84.0
# 37  It's all quite French, but not particularly co...       NEGATIVE   88.0
# 38  My Best Part, the new French dramedy written a...       NEGATIVE   88.0
# 39  If only the film had expanded this focus [on A...       NEGATIVE   88.0
