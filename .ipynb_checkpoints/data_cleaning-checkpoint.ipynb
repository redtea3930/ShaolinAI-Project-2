# %%
from pathlib import Path
import pandas as pd

# %%
# Read in starting data
massive_movies = pd.read_csv('massive_rotten_tomatoes_movies.csv')
massive_reviews = pd.read_csv('massive_rotten_tomatoes_movie_reviews.csv')

# %%
# Combine into one DataFrame, begin cleaning data
massive = pd.merge(massive_movies, massive_reviews, how='inner')
# Out:
#                      id           title  audienceScore  tomatoMeter  \
# 0             love_lies      Love, Lies           43.0          NaN
# 1             love_lies      Love, Lies           43.0          NaN
# 2           adrift_2018          Adrift           65.0         69.0
# 3           adrift_2018          Adrift           65.0         69.0
# 4           adrift_2018          Adrift           65.0         69.0
# ...                 ...             ...            ...          ...
# 1469538  the-human-body  The Human Body           71.0         89.0
# 1469539  the-human-body  The Human Body           71.0         89.0
# 1469540  the-human-body  The Human Body           71.0         89.0
# 1469541  the-human-body  The Human Body           71.0         89.0
# 1469542  the-human-body  The Human Body           71.0         89.0
#
#           reviewId creationDate        criticName  isTopCritic reviewState  \
# 0          2739073   2020-10-31       James Mudge        False       fresh
# 1          2333658   2016-06-15        Diva Velez        False       fresh
# 2        102694850   2022-05-29       Josh Parham        False       fresh
# 3        102654799   2022-02-11     Cory Woodroof        False       fresh
# 4          2816011   2021-08-21        Kip Mooney        False      rotten
# ...            ...          ...               ...          ...         ...
# 1469538     276085   2001-12-29        Bruce Feld        False       fresh
# 1469539     276083   2001-12-29     Bridget Byrne        False      rotten
# 1469540     276084   2001-12-29      Ross Anthony        False       fresh
# 1469541     276086   2001-12-29     John Petrakis         True       fresh
# 1469542     276089   2001-12-29  Robert W. Butler        False       fresh
#
#                      publicatioName  \
# 0                  easternKicks.com
# 1                 TheDivaReview.com
# 2                 Next Best Picture
# 3                          615 Film
# 4              College Movie Review
# ...                             ...
# 1469538  Film Journal International
# 1469539          Boxoffice Magazine
# 1469540       Hollywood Report Card
# 1469541             Chicago Tribune
# 1469542            Kansas City Star
#
#                                                 reviewText scoreSentiment
# 0        Though let down by its routine love triangle n...       POSITIVE
# 1        While not perfect, Love, Lies is a worthy disc...       POSITIVE
# 2        This is nowhere near the level of other great ...       POSITIVE
# 3        Adrift somehow survives the late reveal, and t...       POSITIVE
# 4        For almost the entire runtime, the only people...       NEGATIVE
# ...                                                    ...            ...
# 1469538  From beginning to end, The Human Body is a rar...       POSITIVE
# 1469539  The impression left is that of a series of sli...       NEGATIVE
# 1469540  Though plenty of room for improvement exists, ...       POSITIVE
# 1469541  My guess is that The Human Body will inspire m...       POSITIVE
# 1469542  A near-seamless melding of science fact, visua...       POSITIVE
#
# [1469543 rows x 12 columns]

# %%
# Create column containing difference between critic and audience scores
massive['delta'] = massive['tomatoMeter'] - massive['audienceScore']
# Out:
# /Users/jim/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Drop unneccesary columns, including input audience and critic scores
massive = massive.drop(columns=['originalScore', 'rating', 'ratingContents', 'releaseDateTheaters',
                                'releaseDateStreaming', 'runtimeMinutes', 'genre', 'originalLanguage',
                                'director', 'writer', 'boxOffice', 'distributor', 'soundMix', 'reviewUrl',
                                'id', 'reviewId', 'creationDate', 'isTopCritic', 'reviewState', 'tomatoMeter',
                                'audienceScore'])

# %%
# Check for nulls
massive.isnull().sum()
# Out:
# id                    0
# title              5470
# audienceScore     70249
# tomatoMeter       71273
# reviewId              0
# creationDate          0
# criticName            0
# isTopCritic           0
# reviewState           0
# publicatioName        0
# reviewText        70284
# scoreSentiment        0
# dtype: int64

# %%
# Null data in these columns either indicate low quality data or will interfere with score calculations,
# drop all nulls
massive = massive.dropna()
# Out:
#                      id           title  audienceScore  tomatoMeter  \
# 2           adrift_2018          Adrift           65.0         69.0
# 3           adrift_2018          Adrift           65.0         69.0
# 4           adrift_2018          Adrift           65.0         69.0
# 5           adrift_2018          Adrift           65.0         69.0
# 6           adrift_2018          Adrift           65.0         69.0
# ...                 ...             ...            ...          ...
# 1469538  the-human-body  The Human Body           71.0         89.0
# 1469539  the-human-body  The Human Body           71.0         89.0
# 1469540  the-human-body  The Human Body           71.0         89.0
# 1469541  the-human-body  The Human Body           71.0         89.0
# 1469542  the-human-body  The Human Body           71.0         89.0
#
#           reviewId creationDate        criticName  isTopCritic reviewState  \
# 2        102694850   2022-05-29       Josh Parham        False       fresh
# 3        102654799   2022-02-11     Cory Woodroof        False       fresh
# 4          2816011   2021-08-21        Kip Mooney        False      rotten
# 5          2812722   2021-08-11    Robin Holabird        False       fresh
# 6          2772153   2021-02-28    Richard Crouse        False      rotten
# ...            ...          ...               ...          ...         ...
# 1469538     276085   2001-12-29        Bruce Feld        False       fresh
# 1469539     276083   2001-12-29     Bridget Byrne        False      rotten
# 1469540     276084   2001-12-29      Ross Anthony        False       fresh
# 1469541     276086   2001-12-29     John Petrakis         True       fresh
# 1469542     276089   2001-12-29  Robert W. Butler        False       fresh
#
#                      publicatioName  \
# 2                 Next Best Picture
# 3                          615 Film
# 4              College Movie Review
# 5                    Robin Holabird
# 6                    Richard Crouse
# ...                             ...
# 1469538  Film Journal International
# 1469539          Boxoffice Magazine
# 1469540       Hollywood Report Card
# 1469541             Chicago Tribune
# 1469542            Kansas City Star
#
#                                                 reviewText scoreSentiment
# 2        This is nowhere near the level of other great ...       POSITIVE
# 3        Adrift somehow survives the late reveal, and t...       POSITIVE
# 4        For almost the entire runtime, the only people...       NEGATIVE
# 5        Shailene Woodley shows no fear diving on and o...       POSITIVE
# 6        What is meant to be a voyage of self-discovery...       NEGATIVE
# ...                                                    ...            ...
# 1469538  From beginning to end, The Human Body is a rar...       POSITIVE
# 1469539  The impression left is that of a series of sli...       NEGATIVE
# 1469540  Though plenty of room for improvement exists, ...       POSITIVE
# 1469541  My guess is that The Human Body will inspire m...       POSITIVE
# 1469542  A near-seamless melding of science fact, visua...       POSITIVE
#
# [1295518 rows x 12 columns]

# %%
#Conditionals to isolate reviews where critic scoree is at least 20% either above or below audience scores
condition = (massive['delta'] >= 20) & (massive['scoreSentiment'] == 'POSITIVE')

if condition.any():
    massive = massive.drop(massive[condition].index)

# %%
condition = (massive['delta'] <= -20) & (massive['scoreSentiment'] == 'NEGATIVE')

if condition.any():
    massive = massive.drop(massive[condition].index)

# %%
# Dropping duplicate reviews
massive = massive.drop_duplicates(subset='reviewText', keep='first')
# Out:
#                      id           title  audienceScore  tomatoMeter  \
# 2           adrift_2018          Adrift           65.0         69.0
# 3           adrift_2018          Adrift           65.0         69.0
# 4           adrift_2018          Adrift           65.0         69.0
# 5           adrift_2018          Adrift           65.0         69.0
# 6           adrift_2018          Adrift           65.0         69.0
# ...                 ...             ...            ...          ...
# 1469538  the-human-body  The Human Body           71.0         89.0
# 1469539  the-human-body  The Human Body           71.0         89.0
# 1469540  the-human-body  The Human Body           71.0         89.0
# 1469541  the-human-body  The Human Body           71.0         89.0
# 1469542  the-human-body  The Human Body           71.0         89.0
#
#           reviewId creationDate        criticName  isTopCritic reviewState  \
# 2        102694850   2022-05-29       Josh Parham        False       fresh
# 3        102654799   2022-02-11     Cory Woodroof        False       fresh
# 4          2816011   2021-08-21        Kip Mooney        False      rotten
# 5          2812722   2021-08-11    Robin Holabird        False       fresh
# 6          2772153   2021-02-28    Richard Crouse        False      rotten
# ...            ...          ...               ...          ...         ...
# 1469538     276085   2001-12-29        Bruce Feld        False       fresh
# 1469539     276083   2001-12-29     Bridget Byrne        False      rotten
# 1469540     276084   2001-12-29      Ross Anthony        False       fresh
# 1469541     276086   2001-12-29     John Petrakis         True       fresh
# 1469542     276089   2001-12-29  Robert W. Butler        False       fresh
#
#                      publicatioName  \
# 2                 Next Best Picture
# 3                          615 Film
# 4              College Movie Review
# 5                    Robin Holabird
# 6                    Richard Crouse
# ...                             ...
# 1469538  Film Journal International
# 1469539          Boxoffice Magazine
# 1469540       Hollywood Report Card
# 1469541             Chicago Tribune
# 1469542            Kansas City Star
#
#                                                 reviewText scoreSentiment  \
# 2        This is nowhere near the level of other great ...       POSITIVE
# 3        Adrift somehow survives the late reveal, and t...       POSITIVE
# 4        For almost the entire runtime, the only people...       NEGATIVE
# 5        Shailene Woodley shows no fear diving on and o...       POSITIVE
# 6        What is meant to be a voyage of self-discovery...       NEGATIVE
# ...                                                    ...            ...
# 1469538  From beginning to end, The Human Body is a rar...       POSITIVE
# 1469539  The impression left is that of a series of sli...       NEGATIVE
# 1469540  Though plenty of room for improvement exists, ...       POSITIVE
# 1469541  My guess is that The Human Body will inspire m...       POSITIVE
# 1469542  A near-seamless melding of science fact, visua...       POSITIVE
#
#          delta
# 2          4.0
# 3          4.0
# 4          4.0
# 5          4.0
# 6          4.0
# ...        ...
# 1469538   18.0
# 1469539   18.0
# 1469540   18.0
# 1469541   18.0
# 1469542   18.0
#
# [994149 rows x 13 columns]

# %%
# Output to csv for analysis and processing
massive.to_csv("massive.csv", index=False)
